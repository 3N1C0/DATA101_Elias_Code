# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 2
# ---------------------------------------
#
# GOALS:
#
# 1. Start using Python
# 2. Start looking at Data!
#
# ----------------------------------------------------------
#
# This homework has **TWO** warm-up problems and **FOUR** problems.

# %% [markdown]
# ## Hello World!
#
# ### Warm up Problem 1
#
# Write python code that will print your name and run the cell.

# %%
print("Name: Elias Nicolas")
# Out:
# Name: Elias Nicolas

# %% [markdown]
# ## Installing Modules
#
# ### Warm up Problem 2
#
# Install the modules that you will need to run the rest of the code. You can copy and paste the commands from the class notes. This might take a minute or two to run... go get a cup of coffee :)

# %%
# !conda install -y numpy
# !conda install -y pandas
# !conda install -y matplotlib
# !conda install -y plotly
# !conda install -y itables
# !conda install -y statsmodels
# !conda install -y -c conda-forge python-kaleido
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: /
#
# # All requested packages already installed.
#
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: /
#
# # All requested packages already installed.
#
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: -
#
# # All requested packages already installed.
#
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: /
#
# # All requested packages already installed.
#
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: -
#
# # All requested packages already installed.
#
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: -
#
# # All requested packages already installed.
#
# Jupyter detected...
# 2 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): -
# doneing environment: /
#
# # All requested packages already installed.

# %% [markdown]
# ## Let's do some Data Science.
#
# We will explore some data about how countries vote at the United Nations General Assembly. You should follow along with the notes and/or class video.
#
# I am breaking this into parts and having you copy and paste the code so you can start to identify what the different parts of the code do.

# %% [markdown]
# -------------------------------
# ### Importing Packages:
# -------------------------------
#
# Every time we start a new project we will import the packages that will help us do the analysis. Copy and paste all of the imports in the cell below.
#
# * numpy = mathematical and number packages for python
# * pandas = pretty tables, dataframes, and data analysis packages
# * matplotlib.pyplot = nice looking graphs
# * plotly = nice looking graphs.
# * itables = pretty looking tables that have a search bar

# %%
import pandas as pd 
import numpy as np 

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.default='colab'

from itables import show

# %% [markdown]
# -------------------------------
# ### Get the Data:
# -------------------------------
#
# We will practice all sorts of ways to get data into our notebooks. When you use Pandas (pd) to read a csv:
#
#     DF = pd.read_csv(file_location)
#
# you are basically reading in a spreadsheet (Excel). The data for today is stored on my website.
#
# It might take a minute for the data to load.

# %%
file_location = 'https://joannabieri.com/introdatascience/data/unvotes.csv'
DF = pd.read_csv(file_location)
years = [int(d.split('-')[0]) for d in DF['date']]
DF['year'] = years
DF = DF.drop('Unnamed: 0',axis=1)

# %% [markdown]
# -------------------------------
# ### Initial Data Exploration:
# -------------------------------
# -------------------------------
# ### Show the Data:
# -------------------------------
#
# We want to look at what we have. The data is now represented by the variable DF.

# %%
show(DF)

##prints number of rows
row_count = DF.shape[0]
print(row_count)

#prints number of columns 
column_count = DF.shape[1]
print(column_count)

#prints number of countries 
list_country = list(DF['country'].unique())
print(len(list_country))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_0eea4799_bbaf_479e_a9bd_e95af5f196ea"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_0eea4799_bbaf_479e_a9bd_e95af5f196ea:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "text_in_header_can_be_selected": true, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "downsampling_warning": "<a href=\"https://mwouts.github.io/itables/downsampling.html\">downsampled</a> from 857,878x15 to 546x15 as maxBytes=64KB", "filtered_row_count": 857332, "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>rcid</th>\n      <th>country</th>\n      <th>country_code</th>\n      <th>vote</th>\n      <th>session</th>\n      <th>importantvote</th>\n      <th>date</th>\n      <th>unres</th>\n      <th>amend</th>\n      <th>para</th>\n      <th>short</th>\n      <th>descr</th>\n      <th>short_name</th>\n      <th>issue</th>\n      <th>year</th>\n    </tr>\n  </thead></table>", "data_json": "[[6, \"United States\", \"US\", \"no\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Canada\", \"CA\", \"no\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Cuba\", \"CU\", \"yes\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Dominican Republic\", \"DO\", \"abstain\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Mexico\", \"MX\", \"yes\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Guatemala\", \"GT\", \"no\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Honduras\", \"HN\", \"yes\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"El Salvador\", \"SV\", \"abstain\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Nicaragua\", \"NI\", \"yes\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Panama\", \"PA\", \"abstain\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Colombia\", \"CO\", \"abstain\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THAT AN ITEM ON A DECLARATION OF THE RIGHTS AND DUTIES OF MAN BE TABLED.\", \"hr\", \"Human rights\", 1946], [6, \"Venezuela\", \"VE\", \"no\", 1, 0.0, \"1946-01-04\", \"R/1/107\", 0.0, 0.0, \"DECLARATION OF HUMAN RIGHTS\", \"TO ADOPT A CUBAN PROPOSAL (A/3-C) THA ...
# 857878
# 15
# 200

# %% [markdown]
# ### Problem 1
#
# Do some initial exploration of this data and write about it in the markdown cell below.
#
# * How man columns are there?
# * What do the columns represent?
# * What countries are there?
# * Can you search for a country you are interested in?
# * How many rows are there?
# * What other observations do you have?

# %% [markdown]
# **There are 15 columns.**
#
# **The columns in this dataset represent the specifications of what different countries voted for on certain issues and when.**
#
# **United States, Canada, Cuba, Dominican Republic, Mexico, Guatemala, Honduras, El Salvador, Nicaragua, Panama, Colombia, Venezuela, Ecuador, Peru, Brazil, Bolivia, Paraguay, Chile, Argentina, Uruguay, United Kingdom, Netherlands, Belgium, Luxembourg, France, Poland, Czechoslovakia, Yugoslavia, Greece, Russia, Ukraine, Belarus, Norway, Denmark, Liberia, Ethiopia, South Africa, Iran, Turkey, Iraq, Egypt, Syria, Lebanon, Saudi Arabia, Taiwan, India, Philippines, Australia, New Zealand, Costa Rica, Haiti, Sweden, Iceland, Afghanistan, Yemen Arab Republic, Pakistan, Thailand, Myanmar (Burma), Israel, Indonesia, Hungary, Jordan, Sri Lanka, Spain, Romania, Ireland, Portugal, Austria, Italy, Albania, Bulgaria, Finland, Morocco, Tunisia, Libya, Sudan, Nepal, Cambodia, Laos, Japan, Ghana, Malaysia, Guinea, Cyprus, Mali, Senegal, Benin, Niger, Côte d’Ivoire, Burkina Faso, Togo, Cameroon, Nigeria, Gabon, Central African Republic, Chad, Congo - Brazzaville, Somalia, Madagascar, Congo - Kinshasa, Mauritania, Sierra Leone, Mongolia, Tanzania, Jamaica, Trinidad & Tobago, Uganda, Burundi, Rwanda, Algeria, Kuwait, Kenya, Zanzibar, Malta, Zambia, Maldives, Malawi, Singapore, Guyana, Gambia, Lesotho, Barbados, Botswana, Yemen People's Republic, Mauritius, Equatorial Guinea, Eswatini, Fiji, Bahrain, Qatar, China, Oman, United Arab Emirates, Bhutan, Federal Republic of Germany, German Democratic Republic, Bahamas, Bangladesh, Grenada, Guinea-Bissau, Cape Verde, São Tomé & Príncipe, Mozambique, Comoros, Papua New Guinea, Suriname, Angola, Djibouti, Vietnam, Samoa, Seychelles, St. Lucia, Solomon Islands, Zimbabwe, Vanuatu, Antigua & Barbuda, Belize, St. Vincent & Grenadines, Dominica, St. Kitts & Nevis, Brunei, Liechtenstein, Namibia, Germany, Estonia, Latvia, Lithuania, Yemen, North Korea, South Korea, Marshall Islands, Micronesia (Federated States of), Croatia, Slovenia, Moldova, San Marino, Armenia, Azerbaijan, Bosnia & Herzegovina, Kazakhstan, Tajikistan, Turkmenistan, Kyrgyzstan, Andorra, Czechia, Slovakia, North Macedonia, Monaco, Georgia, Eritrea, Uzbekistan, Palau, Tonga, Nauru, Tuvalu, Kiribati, Switzerland, Timor-Leste, Montenegro, South Sudan**
#
# **Yes, you can search for the county you are intrested in.**
#
# **There are 857878 rows.**
#
# **N/A**

# %% [markdown]
# -------------------------------
# ### Make Python Explore the Data!:
# -------------------------------
#
# Copy and paste the command that will show you a list of the counties:

# %%
#prints the list of countries no quotes
list_country = list(DF['country'].unique())
print('[%s]'%', '.join(list_country))

##prints table
##show(pd.DataFrame(list_country, columns = ['country']))

##Shows data from a specific country
##DF[DF['country'] == 'Peru']
# Out:
# [United States, Canada, Cuba, Dominican Republic, Mexico, Guatemala, Honduras, El Salvador, Nicaragua, Panama, Colombia, Venezuela, Ecuador, Peru, Brazil, Bolivia, Paraguay, Chile, Argentina, Uruguay, United Kingdom, Netherlands, Belgium, Luxembourg, France, Poland, Czechoslovakia, Yugoslavia, Greece, Russia, Ukraine, Belarus, Norway, Denmark, Liberia, Ethiopia, South Africa, Iran, Turkey, Iraq, Egypt, Syria, Lebanon, Saudi Arabia, Taiwan, India, Philippines, Australia, New Zealand, Costa Rica, Haiti, Sweden, Iceland, Afghanistan, Yemen Arab Republic, Pakistan, Thailand, Myanmar (Burma), Israel, Indonesia, Hungary, Jordan, Sri Lanka, Spain, Romania, Ireland, Portugal, Austria, Italy, Albania, Bulgaria, Finland, Morocco, Tunisia, Libya, Sudan, Nepal, Cambodia, Laos, Japan, Ghana, Malaysia, Guinea, Cyprus, Mali, Senegal, Benin, Niger, Côte d’Ivoire, Burkina Faso, Togo, Cameroon, Nigeria, Gabon, Central African Republic, Chad, Congo - Brazzaville, Somalia, Madagascar, Congo - Kinshasa, Mauritania, Sierra Leone, Mongolia, Tanzania, Jamaica, Trinidad & Tobago, Uganda, Burundi, Rwanda, Algeria, Kuwait, Kenya, Zanzibar, Malta, Zambia, Maldives, Malawi, Singapore, Guyana, Gambia, Lesotho, Barbados, Botswana, Yemen People's Republic, Mauritius, Equatorial Guinea, Eswatini, Fiji, Bahrain, Qatar, China, Oman, United Arab Emirates, Bhutan, Federal Republic of Germany, German Democratic Republic, Bahamas, Bangladesh, Grenada, Guinea-Bissau, Cape Verde, São Tomé & Príncipe, Mozambique, Comoros, Papua New Guinea, Suriname, Angola, Djibouti, Vietnam, Samoa, Seychelles, St. Lucia, Solomon Islands, Zimbabwe, Vanuatu, Antigua & Barbuda, Belize, St. Vincent & Grenadines, Dominica, St. Kitts & Nevis, Brunei, Liechtenstein, Namibia, Germany, Estonia, Latvia, Lithuania, Yemen, North Korea, South Korea, Marshall Islands, Micronesia (Federated States of), Croatia, Slovenia, Moldova, San Marino, Armenia, Azerbaijan, Bosnia & Herzegovina, Kazakhstan, Tajikistan, Turkmenistan, Kyrgyzstan, Andorra, Czechia, Slovakia, North Macedonia, Monaco, Georgia, Eritrea, Uzbekistan, Palau, Tonga, Nauru, Tuvalu, Kiribati, Switzerland, Timor-Leste, Montenegro, South Sudan]

# %% [markdown]
# Copy and paste the command that will count up the number of countries:

# %%
#prints number of countries 
list_country = list(DF['country'].unique())
print(f"There are {len(list_country)} different countries in the dataset")
# Out:
# There are 200 different countries in the dataset

# %% [markdown]
# ### Problem 2
#
# Try writing some code for your self. Above we found a countries list by focusing on the column named 'country'. See if you can redo that same code but change it to focus on the column named 'issue'.
#
# What do I expect here:
#
# * First copy and past the code from above
# * Then change that code slightly
# * Run the cell to see if it worked

# %%
#prints the list of various issues in a table 
issues_list = list(DF['issue'].unique())

show(pd.DataFrame(issues_list, columns = ['issue']))
# Out:
# <!--| quarto-html-table-processing: none -->
# <table id="itables_4f81b238_55e7_4f56_82be_08511e4728ae"><tbody><tr>
#     <td style="vertical-align:middle; text-align:left">
#     <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
#     Loading ITables v2.5.2 from the internet...
#     (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
#     </tr></tbody></table>
# <link href="https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import { ITable, jQuery as $ } from 'https://www.unpkg.com/dt_for_itables@2.4.0/dt_bundle.js';
#
#     document.querySelectorAll("#itables_4f81b238_55e7_4f56_82be_08511e4728ae:not(.dataTable)").forEach(table => {
#         if (!(table instanceof HTMLTableElement))
#             return;
#
#         let dt_args = {"layout": {"topStart": null, "topEnd": null, "bottomStart": null, "bottomEnd": null}, "text_in_header_can_be_selected": true, "style": {"table-layout": "auto", "width": "auto", "margin": "auto", "caption-side": "bottom"}, "order": [], "classes": ["display", "nowrap"], "table_html": "<table><thead>\n    <tr style=\"text-align: right;\">\n      \n      <th>issue</th>\n    </tr>\n  </thead></table>", "data_json": "[[\"Human rights\"], [\"Economic development\"], [\"Colonialism\"], [\"Palestinian conflict\"], [\"Arms control and disarmament\"], [\"Nuclear weapons and nuclear material\"]]"};
#         new ITable(table, dt_args);
#     });
# </script>

# %% [markdown]
# -------------------------------
# ### Data Visualization:
# -------------------------------
#
# Now we will select three countries that we are interested in and see how their votes have changed over time. Below you should see code that selects: Turkey, United States, and United Kingdom.
#
# **IMPORTANT** These have to be spelled and capitalized exactly like they are in the data. Python is unforgiving of typos!
#
# You can just run the cell below - assuming you have done all the parts above!

# %%
countries = ['Peru', 'Ecuador', 'Canada']
issues = list(DF['issue'].unique())
c_groups = DF.groupby(['country','issue'])
print(issues)
# Out:
# ['Human rights', 'Economic development', 'Colonialism', 'Palestinian conflict', 'Arms control and disarmament', 'Nuclear weapons and nuclear material']

# %% [markdown]
# Now that we have our focus countries, we can make pretty pictures.
#
# You can just run the cell below - assuming you have done all the parts above!

# %%
def make_plot(countries,issue):
    '''
    A Python function that takes in the list of countries and issues and makes
    a scatter plot of each issue with a trendline for each country.
    '''
    x_data = []
    y_data = []
    c_data = []
    for cntry in countries:
        my_group = c_groups.get_group((cntry,issue))
        for y in my_group['year'].unique():
            x_data.append(y)
            tot_yes = sum(my_group[my_group['year']==y]['vote']=='yes')
            percent_yes = tot_yes/len(my_group[my_group['year']==y])*100
            y_data.append(percent_yes)
            c_data.append(cntry)

    fig = px.scatter(x=x_data, y=y_data,color=c_data,trendline="lowess",labels={"color": "Country"})

    fig.update_layout(
        title={
            'text': issue + '<br>',
            'y':0.9,
            'x':0.5,
            'xanchor': 'center',
            'yanchor': 'top'})
    fig.update_yaxes(title_text="% Yes")
    fig.update_xaxes(title_text="Year")
    fig.show()
    
for iss in issues:
    make_plot(countries,iss)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="fe89692f-6fe7-47c8-8f74-0e91180574aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fe89692f-6fe7-47c8-8f74-0e91180574aa")) {                    Plotly.newPlot(                        "fe89692f-6fe7-47c8-8f74-0e91180574aa",                        [{"hovertemplate":"Country=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Peru","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpgenB6kHqgetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9YH1QfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAASUCqqqqqqqowQAAAAAAAAFlAAAAAAAAAAAAAAAAAAMBCQAAAAAAAAElAAAAAAAAAAACqqqqqqqpAQFZVVVVV1VRAAAAAAAAAWUCqqqqqqqpAQAAAAAAAADlAAAAAAAAAAAAAAAAAAABJQAAAAAAAAFlAAAAAAAAAREAAAAAAAABZQAAAAAAAAERAt23btm3bUUAdx3Ecx3FTQAAAAAAA4FVAVlVVVVX1V0DyGsprKK9XQM\u002fzPM\..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Peru","showlegend":false,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpgenB6kHqgetB64HrwewB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"3z4fS9GeNUBzlyPAuTE5QIQZEcmJ\u002fDpA36ijghTIPEAhzFUKjDBAQFX4XGpDF0FAJZqfwjf+QUBu07zLPuVCQIdrRIknzENArvoA6uKYRUC7e95XUH5GQCtQeVtJRkhAdmUjOYQoSUDkVjMxOcdLQJairQ8qpExAlC1u4yOATUDAp+PM11tOQAVGfUq0OE9AfEei04MMUEBH7FuRa39QQDpos2CA9FBACVt2VIJqUUBhtWg\\u002fdVWNBjlRAKLT86MF2VEDDJAN4T19UQMnM5X31R1RAEMk6pb8wVEC61RoHuRlUQGQ3QIXrAlRATxS1XGHsU0CURMkSItZTQP1Cd7MywFNA8t4p0JuqU0A76HHoZJVTQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Ecuador","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpgenB6kHqgeuB68HsAexB7IHswe0B7UHtge3B7gHuQe6B7sHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfWB9UH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Ecuador","showlegend":false,"x":{"dtype":"i2","bdata":"mgecB50HngegB6EHogejB6QHpgenB6kHqgeuB68HsAexB7IHswe0B7UHtge3B7gHuQe6B7sHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"CKq0rFPaSkBcHdTPMsNLQMg3oxnKNkxAOxbkbeKpTEAPHoMc+45NQNd ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="40649a9f-4975-42c3-a89f-645614c9787d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("40649a9f-4975-42c3-a89f-645614c9787d")) {                    Plotly.newPlot(                        "40649a9f-4975-42c3-a89f-645614c9787d",                        [{"hovertemplate":"Country=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Peru","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB6AHoQeiB6MHpAelB6YHpwepB6oHqweuB68HsAexB7IHswe0B7UHtge3B7gHuQe7B7oHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"\..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Peru","showlegend":false,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB6AHoQeiB6MHpAelB6YHpwepB6oHqweuB68HsAexB7IHswe0B7UHtge3B7gHuQe6B7sHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"Esi6c3BjTUD71kWfuAVOQFQAxHxZp05AwJlVdVRIT0AxtKkisehPQB4B6S\u002fck1BAbJro0T7jUEACC2yGbTJRQJWkxHFzgVFAC15kT17QUUCPNOEgPx9SQBiCBRUrblJAR5OtVTy9UkCr\u002ffO+RlxTQOQL2ViErFNA1a94xnv9U0BsgoWEb\u002fdUQErzF0BVTVVAhNPIT8SiVUCrB4hJq\\u002fCnVe5dYQLlUzEsGlFhA9YCuS5mQWEAWDqOjJI1YQO86sr6biVhAx0VkivSFWEC9eb+4JoJYQCv+xP4rflhAUGfuqQF6WED2WEl7pnVYQNCubHUccVhAndXXl2ZsWEDmEvvXhmdYQGByrL1+YlhAB9wvDVJdWECB5\u002fJ5BFhYQB9UpMKbUlhAggGQvR5NWEA="},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Ecuador","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB6AHoQeiB6MHpAelB6YHpwepB6oHqweuB68HsAexB7IHswe0B7UHtge3B7gHuQe7B7oHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"\..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecua ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="9d499a61-2507-408f-8ff0-feb73e859661" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9d499a61-2507-408f-8ff0-feb73e859661")) {                    Plotly.newPlot(                        "9d499a61-2507-408f-8ff0-feb73e859661",                        [{"hovertemplate":"Country=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Peru","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB58HoAehB6IHowelB6QHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"\"},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Peru","showlegend":false,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB58HoAehB6IHowekB6UHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"6AMKSPmKRkBE9cwDGzBHQEVq0mfN1UdAwgOZWwZ8SECQK2U8uiJJQHTb9bngyUlAGZ6GoHFxSkDNj9fVYxlLQF5HCv+twUtAykQ3r0FqTEBasI9sBBNNQOUMGjrNu01AjOxqQ78MT0AoOIx8lrRPQL7asVriLVBAH8JlPRCBUEA4cek8wtNQQBVGECRgd1FA1z4q2SbIUUDibGa\u002fRRhSQAPmzUgLaFJAQmiODnO4UkBTCO\u002fVnAtTQB0uVLgMZFNAVI88kP+8U0Dji02A0BVUQB1tAsGKbVRAz9BiWvbCVECLJ3\u002fUuxRVQPLnojaNYVVAxVx8\u002fGeoVUCdHFBslehVQPrckyTKIVZATxN\u002fUjVUVkCS2uypXIBWQCeOWsOmplZAeUH4KpXHVkC8OKS\u002f4uNWQPouDw4i\u002fFZA3A1CqHkQV0CKJmLkxjBXQMdlCEOwO1dAls7xq5hCV0DocjaTKkZXQCoKMDk7R1dAL4wc1ptGV0DIDZ0a5URXQEMAmjQ9QldAyTc\u002fjkY+V0DlFBZ\u002feDRXQCfNnPZULFdAKGPdnUglV0BusOcWyh5XQOsXbriMGFdAIfVUA2oSV0AdIbpFTwxXQCR6uZE0BldASUXJHhgAV0CBczMi\u002fPlWQLLzbUjl81ZArpnvM9rtVkB29P+r4udWQFCRNVAI4lZAaSwvDlTcVkApx1S9zdZWQAAJoFt80VZAFl+M2GXMVkAfb+Vcj8dWQFNnhIn+wlZAjv8ZNbm+VkBGJoVLxbpWQIxyPvEot1ZA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Ecuador","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mgebB5wHnQeeB58HoAehB6IHowelB6QHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"JEmSJEmSLEByHMdxHMdLQKqqqqqqqlBAqqqqqqqqUEAAAAAAAMBSQAAAAAAAAFlAJUmSJEkSUEByHMdxHMdLQA ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="304d81df-ec82-420d-af17-648974d8cdb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("304d81df-ec82-420d-af17-648974d8cdb0")) {                    Plotly.newPlot(                        "304d81df-ec82-420d-af17-648974d8cdb0",                        [{"hovertemplate":"Country=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Peru","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mwecB50HngegB6UHpAepB6oHrQevB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Peru","showlegend":false,"x":{"dtype":"i2","bdata":"mwecB50HngegB6QHpQepB6oHrQevB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"Y9F+9GnkVEDfvQg+BAJVQJ8ttx4cH1VAxl7HNbk7VUA1bwLCnXNVQEXaz+Zg31VAnMyI6Ab6VUAoONrnBWdWQNNEXIKig1ZApA\u002f\u002f9KDgVkDUzbpFsihXQK8LIfqkfVdAhGFHS2ysV0BfLM18IdlXQHAVwNnd+VdAhJxWU58AWEAbOXXtZQFYQKkr9aP+\u002fFdAmoysLHT0V0ClsfJ9ludXQEZSwfd62VdANB\u002fApq\u002fJV0CDxhzapblXQAM+7jpvqFdAqFLyfNSWV0AmuYE+LIVXQGXGPsFpcVdAp5lJVx5cV0Bi1rQLhklXQKNI+7b+MVdAQa3p6+oYV0CDD+G0KAZXQMeYYFMk61ZAGg6\"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Ecuador","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"mwecB50HngegB6UHpAepB6oHqwevB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH1AfTB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"...\u002fM8z1dAAAAAAACAVkC66KKLLrpWQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQPM8z\u002fM8z1dAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUA7sRM7sRNXQAAAAAAAAFlAAAAAAAAAWUBu27Zt2zZXQA=="},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Ecuador","showlegend":false,"x":{"dtype":"i2","bdata":"mwecB50HngegB6QHpQepB6oHqwevB7EHsgezB7QHtQe2B7cHuAe5B7oHuwe8B70Hvge\u002fB8AHwQfCB8MHxAfFB8YHxwfIB8kHygfLB8wHzQfOB88H0AfRB9IH0wfUB9UH1gfXB9gH2QfaB9sH3AfdB94H3wfgB+EH4gfjBw=="},"xaxis":"x","y":{"dtype":"f8","bdata":"qCF77RPHUUDhlOUP49RRQBIJ8BEW41FAammZ3bfxUUBf7LjHRxBSQHBk7vrfUVJApRwn1uFiUkAOFAeCOaVSQP4u+Z3js1JAwjkECK7AUkA2DcYjF8BSQFC7eP2nXFJAmQQcKynnUUCd6 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="b53048b5-1203-40ad-8852-2de135bf5e85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b53048b5-1203-40ad-8852-2de135bf5e85")) {                    Plotly.newPlot(                        "b53048b5-1203-40ad-8852-2de135bf5e85",                        [{"hovertemplate":"Country=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Peru","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"nAedB6IHpAelB6YHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuwe6B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Peru","showlegend":false,"x":{"dtype":"i2","bdata":"nAedB6IHpAelB6YHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"Mzk5oKR3S0BcNNtsNxVMQPgH9WHbGk9A4vJPG\u002fgjUECG4TKNGm5QQHjFJI9kt1BARVl1PNP\u002fUEBZrLrQbUdRQF\u002fHjlpAjlFATWne3V\u002fUUUADqw585xlSQGjzh124o1JAtmKwwFXoUkBVnzMI\\u002fkJkfqepV0A3UTkRSsBXQAU46+wg1ldABmbbQyjrV0AStJTDW\u002f9XQDiwk8bEElhAuCh6nYIhWEAFuV1RMzBYQNdMXIv8PlhAzysvldlNWED3CEq4tFxYQO13rCN4a1hAKxDrQxJ6WECZMTn3dohYQFRN7jmhllhAO1TSlo6kWEBLYSRiP7JYQHbs+ie1v1hAEXimdvTMWEABrlK+AdpYQPyV6pvg5lhAmX9kEZTzWECU9dixHgBZQEhVsceCDFlAZ1+feMIYWUDmyojp3yRZQBcVuWPdMFlA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Ecuador","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"nAedB54HpAelB6YHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuwe6B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Ecuador","showlegend":false,"x":{"dtype":"i2","bdata":"nAedB54HpAelB6YHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"BRqupXPlVkCuW9tJTfVWQDS8Lu37BFdAOiYuu5dcV0DFNB8Kb2lXQDidS\u002fOGdVdABmt6AciAV0Cz86Z3IItXQFFKfpqUlFdAkzpgoj2dV0CEnebcPKVXQFGkq5\u002fKs1dA9j6QVaq6V0DPONgOh8FXQAlTmFmeyFdA\u002fiK9kjTQV0ByVZ33jdhXQHfBJyfi4VdAjmpE8EbsV0DB+Ei5Ae9XQOBSiqL+71dAWORSGXTvV0A8LRidxvRXQHn5u5NQ9ldAeltY69XtV0CB+EWV7ONXQAM16gmC2VdAGP8Pep\u002fPV0DC12zwcsdXQFPFZo2nwVdAs6Ba2jO+V ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.0.min.js" integrity="sha256-Ei4740bWZhaUTQuD6q9yQlgVCMPBz6CZWhevDYPv93A=" crossorigin="anonymous"></script>                <div id="2cd78c7e-5f50-4f36-9d92-23ccdf0d4bf6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2cd78c7e-5f50-4f36-9d92-23ccdf0d4bf6")) {                    Plotly.newPlot(                        "2cd78c7e-5f50-4f36-9d92-23ccdf0d4bf6",                        [{"hovertemplate":"Country=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Peru","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"nQelB6YHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuwe6B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Peru\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Peru","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Peru","showlegend":false,"x":{"dtype":"i2","bdata":"nQelB6YHpweoB6kHqgerB60HrgevB7AHsQeyB7MHtAe1B7YHtwe4B7kHuge7B7wHvQe+B78HwAfBB8IHwwfEB8UHxgfHB8gHyQfKB8sHzAfNB84HzwfQB9EH0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH"},"xaxis":"x","y":{"dtype":"f8","bdata":"5WI\u002faYrhSECQn8Cv+FtOQHVP3aCTCk9A3fuPIba4T0BAwQKLJDNQQPp2S+OciVBAAUbXgbbfUEC1VVnTYjVRQKbG6uxG31FAkH9g43YzUkChODy7J4dSQDQ9TS1j2lJATdjiXz0tU0CpL6Z12n9TQHYSg\u002fZ60lNAa9VxrpolVECR+sQPDHpUQB\u002fy2YhPy1RAjcnpxf0iVUAW+TAoVH1VQDvuwlym1FVA8GGWVhEXVkBOjM6BHk9WQHJjLOPaflZAQ5rGFkqoVkAB6KyFns1WQMeZHRcr8FZAiloT0coQV0CPp7Ok7zVXQEvA2zFdUldACeGd561sV0C+W48CW4RXQAh4ru\u002f+mFdAmb4UVsWqV0AiMyW4ULpXQLDp6utqyFdAB3PYia\u002fVV0D\u002fDycHWuJXQI0Y2ZCh7ldAfPYgytf6V0A4XK+OYwdYQPBf7s96FFhA7GU2BAMiWEDOf\u002fs5Ey9YQEodSzuPPFhAh4\u002fNRUpKWEDHsExKHVhYQJbYfm7mZVhAyFoFdotzWEBazM8H+4BYQBrF9RUvjlhAIcbRcCWbWEA175A84KdYQNRiFR9jtFhAuu1qk7XAWECQ7NaL3sxYQLX384bj2FhAiDv65cjkWED3CxgrkvBYQOxIeixC\u002fFhA7IgsQ9sHWUA09cV5XxNZQNU7B73QHllA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Ecuador","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"nAedB6UHpgenB6gHqQeqB6sHrQeuB68HsAexB7IHswe0B7UHtge3B7gHuQe7B7oHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"..."},"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eLOWESS trendline\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eCountry=Ecuador\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Ecuador","showlegend":false,"x":{"dtype":"i2","bdata":"nAedB6UHpgenB6gHqQeqB6sHrQeuB68HsAexB7IHswe0B7UHtge3B7gHuQe6B7sHvAe9B74HvwfAB8EHwgfDB8QHxQfGB8cHyAfJB8oHywfMB80HzgfPB9AH0QfSB9MH1AfVB9YH1wfYB9kH2gfbB9wH3QfeB98H4AfhB+IH4wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"lBmbx1gXU0CPnP0ZmFtTQAxWt0UiTVVAQAw2GnKDVUBrWNwovrdVQJzk3Pon6lVAu31OO+UaVkC1UtdENEpWQEL++CpZeFZAFzMpyT\u002fSVkAdX5nGlf5WQPV\u002fnV3oKldA7fGB6INXV0DNQX0KqoRXQOjhYb6DsldASPgEvgrhV0AglJC63A9YQOWeCsxNLVhATc+bsIdDWEDF8qtS0mNYQGPxS0SpelhAE6k+rIKBWEBYjPPl\u002f3VYQEOw7NTOYVhAoepcnqNOWED8wvEHvD1YQPqTZL6XL1hAiyr\u002fQlkkWECClx\u002fw2RtYQJoc6xGKFVhA7ZDmYJ8QWEATqltsjwxYQHo0p8gbCVhA26ukuDgGWECDRgPzAg ...

# %% [markdown]
# ### Problem 3
#
# Choose one of the graphs produced above (should match the lecture notes) and discuss what you see there:
#
# 1. Which issue are you focusing on.
# 2. What do the graph axis represent?
# 3. Say in words how the United States votes have changed over time.
# 4. How do the United States votes compare to the other countries?
# 5. See if you can come up with one or two questions that interest you about the data in the graph.

# %% [markdown]
# **I am focusing on the issue Palenstinian Conflict, analzing the United States, United Kingdom, and Turkey specifically.**
#
# **The x-axis represents the year the vote took place and the y-axis represents the percentage of countries that said yes on the issue at hand.**
#
# **The United States have voted "No" more and more over time, seeing a decrease over time in the percentage of "Yes" votes.**
#
# **United States are the polar opposite compared to other countries, with most countries voting "Yes" on the issue in more recent times while the United States tends to vote "No".**
#
# **Question 1: What cause the United States and United Kingdom to essentially switch roles over time?**
#
# **Question 2: What United States party had more influence in office when these decisions were made, does Republican or Democratic influence matter in these foreign issues?**

# %% [markdown]
# ### Problem 4
#
# Now go back up to where we picked our three focus countries and choose some different ones. Rerun the analysis. If you want you could choose more than three countries.
#
# Discuss the graph for the same issue but with the new countries.

# %% [markdown]
# **I am still discussing the same issues from the previous section, the Palenstinian Conflict. The countries I am focusing on are Canada, Peru, and Ecuador.**
#
# **Canada has a very similar graph trajectory to the United States, with the percentages of votes in the "Yes" direction decreasingly drastically during recent times.**
#
# **Peru and Ecuador on the other had are on the other end of the spectrum, where their percentage of "Yes" votes range from 80 to 100 percent.**
#
# **Peru and Ecuador share a very similar voting pattern while Canada seems to vote similarly to the United States, does geography play a role in voting? If so then why are western countries voting "No" on this subject while South American countries are voting "Yes".**

# %% [markdown]
# --------------------------------
# ### You are done with the homework... now what?
# --------------------------------
#
# 1. Save your changes.
# 2. In the Git tab, **Stage** your changed files - use the (+) button next to the file.
# 3. **Commit** your changes by entering a summary and pushing commit.
# 4. **Push** your changes using the cloud button.
# 5. Check that your changes are on your GitHub repo (online)
# 6. **TAKE THE DAILY QUIZ ON CANVAS** the quiz will ask you to copy and past the HTTPS link to your repo for the day.
# 7. Come to class and get your questions answered.
#
# At the end of the week  you will submit your final versions of the homework on Canvas for grading. For this you can just drag and drop the HW.ipynb files into canvas.
#
# **IMPORTANT** If this is confusing this first week, don't worry, I can help you and I will be really flexible about these first few deadlines.

# %%
print("Done")
